# %%
pip install pytesseract

# %%
import cv2
import pytesseract

# %%
from PIL import Image

# %%
Original_Image = Image.open("/content/inter_image.jpg")
rotated_image1 = Original_Image.rotate(149)
rotated_image1
# Out:
# <PIL.Image.Image image mode=RGB size=1122x859>

# %%
pip install easyocr

# %%
import easyocr

# %%
reader=easyocr.Reader(['en'])
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
output_path ="/content/rot.jpg"
rotated_image1.save(output_path, "JPEG")

# %%
output=reader.readtext(output_path)

# %%
output
# Out:
# [([[646, 374], [700, 374], [700, 398], [646, 398]],
#   'J6 $',
#   0.18373480771505968),
#  ([[397, 373], [441, 373], [441, 429], [397, 429]], '8', 0.5517853964854602),
#  ([[668, 400], [754, 400], [754, 424], [668, 424]],
#   'Oucid',
#   0.03484271280846928),
#  ([[654, 640], [704, 640], [704, 688], [654, 688]], 'psi', 0.8903726770431599),
#  ([[630, 710], [753, 710], [753, 751], [630, 751]], 'MZ"', 0.3573185115640348),
#  ([[625.5144372945836, 192.28609323645895],
#    [690.3551186468873, 187.82211596605566],
#    [691.4855627054164, 224.71390676354105],
#    [626.6448813531127, 229.17788403394434]],
#   '2000',
#   0.7504256963729858),
#  ([[898.1135155856441, 340.09946857683417],
#    [930.5656854249493, 327.0402020253553],
#    [953.8864844143559, 391.90053142316583],
#    [921.4343145750507, 404.9597979746447]],
#   '3',
#   0.26455732971248835),
#  ([[829.0063694429277, 672.4146497187338],
#    [881.4659497859001, 623.2197289590213],
# ...

# %%
cord = output[0][0]
cord
# Out:
# [[646, 374], [700, 374], [700, 398], [646, 398]]

# %%
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]

x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
x_min,y_min
# Out:
# (646, 374)

# %%
import matplotlib.pyplot as plt
image = cv2.imread(output_path)
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
pip install keras_ocr

# %%
import matplotlib.pyplot as plt
import keras_ocr

pipeline = keras_ocr.pipeline.Pipeline()

images = [
    keras_ocr.tools.read(output_path)
]

prediction_groups = pipeline.recognize(images)
for i, data in enumerate(prediction_groups):
    print(data)
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...
# 1/1 [==============================] - 5s 5s/step
# [('2000', array([[632.15753, 195.8349 ],
#        [687.77405, 193.30687],
#        [689.10693, 222.63104],
#        [633.49036, 225.15907]], dtype=float32)), ('ldllle', array([[631.20135, 180.33188],
#        [958.33844, 351.46762],
#        [905.0627 , 453.30756],
#        [577.9256 , 282.1718 ]], dtype=float32)), ('s', array([[469.3277 , 267.78143],
#        [569.52985, 289.30374],
#        [497.75934, 623.44836],
#        [397.5572 , 601.9261 ]], dtype=float32)), ('s', array([[901.9712 , 345.41025],
#        [930.6418 , 333.6814 ],
#        [952.9127 , 388.12134],
#        [924.2421 , 399.8502 ]], dtype=float32)), ('s', array([[410.60892, 372.52853],
#        [439.68607, 380.97028],
#        [424.61017, 432.8984 ],
#        [395.53305, 424.45667]], dtype=float32)), ('ro', array([[650.84766, 380.20898],
#        [674.9531 , 380.20898],
# ...

# %% [markdown]
# # BELOW SHOWS THE EXTRACTED IMAGE

# %%
predicted_image = prediction_groups[0]
for text, box in predicted_image:
    print(text)
# Out:
# 2000
# ldllle
# s
# s
# s
# ro
# ss
# couecin
# d
# ldo0
# psi
# wlkal

# %%
data[0][1]
l=[]
for i in data:
  if i[0]=='psi' or i[0]=='wlkal':
    l.append(i[1])

# %%
data_needed=data[-2][1]
x_min, y_min = [int(min(idx)) for idx in zip(*data_needed)]

x_max, y_max = [int(max(idx)) for idx in zip(*data_needed)]

# %%
import matplotlib.pyplot as plt
image = cv2.imread(output_path)
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
data_needed=data[-1][1]
x_min, y_min = [int(min(idx)) for idx in zip(*data_needed)]

x_max, y_max = [int(max(idx)) for idx in zip(*data_needed)]

# %%
import matplotlib.pyplot as plt
image = cv2.imread(output_path)
cv2.rectangle(image,(x_min,y_min),(x_max,y_max),(0,0,255),2)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
